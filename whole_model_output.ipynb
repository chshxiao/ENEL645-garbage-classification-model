# %%
import matplotlib.pylab as plt
import numpy as npr
from whole_model import *
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
from metrics import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# Evaluation on loss and accuracy from the logistic regression model
# All results come from the output of text model in slurm-28027.out
whole_confusion_matrix = 'whole_model_confusion_matrix.txt'

# %%
# read file
confusion_matrix = np.loadtxt(whole_confusion_matrix)
print(confusion_matrix)
# Out:
# [[235. 231.  43. 186.]
#  [164. 665.  28. 228.]
#  [110.  84. 553.  52.]
#  [ 99. 164.  24. 565.]]

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, cmap='Blues', fmt='g', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
