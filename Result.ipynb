# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
path = '/content/drive/MyDrive/ENEL645-garbage-classification-model'
if not path in sys.path:
  sys.path.append(path)

# %%
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/usr/local/lib/python3.10/dist-packages/setuptools/_vendor', '/root/.ipython', '/content/drive/MyDrive/ENEL645-garbage-classification-model']

# %%
from metrics import *

# %%
# %cd /content/drive/MyDrive/ENEL645-garbage-classification-model
# Out:
# /content/drive/MyDrive/ENEL645-garbage-classification-model

# %%
image_data = pd.read_csv('ImageModelResult.csv')
print(image_data)
# Out:
#     epoch  train_loss  train_accuracy  validation_loss  validation_accuracy
# 0       1       0.978       63.058386            0.884            64.224138
# 1       2       0.844       67.525470            0.834            65.409483
# 2       3       0.794       68.857759            0.960            64.924569
# 3       4       0.796       69.004702            0.858            66.594828
# 4       5       0.772       69.896160            0.843            64.924569
# 5       6       0.762       69.837382            0.907            65.140086
# 6       7       0.748       70.327194            0.821            66.918103
# 7       8       0.744       70.679859            0.806            67.241379
# 8       9       0.727       71.306818            0.836            64.116379
# 9      10       0.730       71.473354            0.766            66.971983
# 10     11       0.718       71.728056            0.835            65.948276
# ...

# %%
plot_loss_function(image_data['train_loss'], image_data['validation_loss'])
plt.title('Image Model Loss Function vs. Epoch')
plt.show()

# %%
plot_accuracy_function(image_data['train_accuracy'], image_data['validation_accuracy'])
plt.title('Image Model Accuracy % vs. Epoch')
plt.show()

# %%
text_data = pd.read_csv('TextModelResult.csv')
print(text_data)
# Out:
#    epoch  train_loss  train_accuracy  validation_loss  validation_accuracy
# 0      1      0.4635         83.0098           0.3333              88.2800
# 1      2      0.2644         90.6176           0.3244              88.7222
# 2      3      0.1981         93.0686           0.3288              89.5556
# 3      4      0.1601         94.4510           0.3400              88.9444
# 4      5      0.1331         95.3431           0.3578              89.6111
# 5      6      0.1182         95.8824           0.3520              89.6111
# 6      7      0.1035         96.3137           0.4138              89.1667
# 7      8      0.0959         96.4510           0.4247              88.9444
# 8      9      0.0891         96.8529           0.4276              89.2222
# 9     10      0.0826         97.0392           0.4358              89.3889

# %%
plot_loss_function(text_data['train_loss'], text_data['validation_loss'])
plt.title('Text Model Loss Function vs. Epoch')
plt.show()

# %%
plot_accuracy_function(text_data['train_accuracy'], text_data['validation_accuracy'])
plt.title('Text Model Accuracy % vs. Epoch')
plt.show()
